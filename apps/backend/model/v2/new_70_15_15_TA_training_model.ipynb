# %% [markdown]
# # Tutorial
# Ganti runtime type dengan klik panah bawah di sebelah tulisan connect dan klik pada change runtime type
# Pilih T4 GPU lalu klik save
# Lalu tinggal jalankan kode di bawah ini hingga mencapai teks "Testing"
#
# Training model memakan waktu sekitar 2 jam, pastikan agar laptop/komputer yang melakukan training tidak masuk idle/tidak digunakan, tetap awasi dengan gerakan kursor mouse agar tidak dianggap diam oleh google colab sehingga tidak terputus koneksi ketika training model
#
# Ketika training selesai, cek dengan klik pada ikon folder/files di sebelah kiri dibawah ikon kunci, lalu cari runs/detect/{} di dalamnya ada folder weights, di sinilah model tersimpan, bisa didownload untuk last.pt atau best.pt

# %% [markdown]
# # Training

# %%
# 1. Install Library dan Download Dataset
# !pip install roboflow tensorflow

from roboflow import Roboflow
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger
import os
import json

# Masukkan API Key Roboflow
rf = Roboflow(api_key="oSqbdWgbnJkiVfOWl18o")
project = rf.workspace("valll-rtclj").project("fmd-and-lsd-cattle-disease")
version = project.version(3)
dataset = version.download("folder")


# 2. Menyiapkan Path Dataset
TRAIN_DIR = f"{dataset.location}/train"
VALID_DIR = f"{dataset.location}/valid"


# 3. Preprocessing Data
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

valid_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

print("🔍 Membaca data dari struktur folder...")

train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=True
)

valid_generator = valid_datagen.flow_from_directory(
    VALID_DIR,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

NUM_CLASSES = train_generator.num_classes

if NUM_CLASSES == 0:
    print("❌ ERROR: Tidak ada kelas yang ditemukan!")
else:
    print(
        f"✅ Ditemukan {NUM_CLASSES} kelas: "
        f"{list(train_generator.class_indices.keys())}"
    )


# 4. Memuat Model MobileNetV3Large
base_model = MobileNetV3Large(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)

base_model.trainable = False


# 5. Menambahkan Layer Klasifikasi
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.2)(x)

predictions = Dense(
    NUM_CLASSES,
    activation='softmax'
)(x)

model = Model(
    inputs=base_model.input,
    outputs=predictions
)


# 6. Kompilasi Model
model.compile(
    optimizer=tf.keras.optimizers.Adam(
        learning_rate=0.001
    ),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()


# 7. Menyiapkan Checkpoint dan Training
BEST_MODEL_PATH = '/content/tes1_best_v3.keras'
LAST_MODEL_PATH = '/content/tes1_last_v3.keras'
CHECKPOINT_DIR = '/content/checkpoints_v3'

os.makedirs(CHECKPOINT_DIR, exist_ok=True)

# Menyimpan model dengan validation accuracy terbaik
best_checkpoint = ModelCheckpoint(
    BEST_MODEL_PATH,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True,
    save_weights_only=False,
    verbose=1
)

# Menyimpan model setiap epoch
epoch_checkpoint = ModelCheckpoint(
    filepath=os.path.join(
        CHECKPOINT_DIR,
        'epoch_{epoch:02d}_valacc_{val_accuracy:.4f}.keras'
    ),
    save_best_only=False,
    save_weights_only=False,
    verbose=0
)

csv_logger = CSVLogger(
    '/content/training_log_v3.csv',
    append=False
)

print("\n🚀 Memulai training MobileNetV3Large selama 50 epoch...")

history = model.fit(
    train_generator,
    epochs=50,
    validation_data=valid_generator,
    callbacks=[
        best_checkpoint,
        epoch_checkpoint,
        csv_logger
    ]
)


# 8. Menyimpan Model dan Nama Kelas
model.save(LAST_MODEL_PATH)

class_indices = {
    v: k
    for k, v in train_generator.class_indices.items()
}

with open('/content/class_names.json', 'w') as f:
    json.dump(class_indices, f, indent=4)

print("\n✅ Training selesai.")
print(f"🏆 Best model : {BEST_MODEL_PATH}")
print(f"📌 Last model : {LAST_MODEL_PATH}")
# Out:
# Collecting roboflow
#   Downloading roboflow-1.4.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.20.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from roboflow) (2026.6.17)
# Requirement already satisfied: idna>=3.7 in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.18)
# Requirement already satisfied: cycler in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.5.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy<2.4,>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.0.2)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (11.3.0)
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.3 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.6.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (2.2 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.32.4)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.67.3)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (6.0.3)
# Requirement already satisfied: requests_toolbelt in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.0.0)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting typer<0.26,>=0.12.0 (from roboflow)
#   Downloading typer-0.25.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (8.4.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (26.2)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.16.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.82.1)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.19.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->roboflow) (3.4.9)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26,>=0.12.0->roboflow) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26,>=0.12.0->roboflow) (0.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (4.63.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow) (2.20.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Downloading roboflow-1.4.0-py3-none-any.whl (285 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.0/285.0 kB 8.5 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 18.5 MB/s eta 0:00:00
# Downloading pi_heif-1.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 39.2 MB/s eta 0:00:00
# Downloading pillow_avif_plugin-1.6.0-cp312-cp312-manylinux_2_28_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 70.7 MB/s eta 0:00:00
# Downloading typer-0.25.1-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 1.8 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Installing collected packages: pillow-avif-plugin, filetype, pi-heif, opencv-python-headless, typer, roboflow
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 5.0.0.93
#     Uninstalling opencv-python-headless-5.0.0.93:
#       Successfully uninstalled opencv-python-headless-5.0.0.93
#   Attempting uninstall: typer
#     Found existing installation: typer 0.26.8
#     Uninstalling typer-0.26.8:
#       Successfully uninstalled typer-0.26.8
# Successfully installed filetype-1.2.0 opencv-python-headless-4.10.0.84 pi-heif-1.4.0 pillow-avif-plugin-1.6.0 roboflow-1.4.0 typer-0.25.1
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format folder in progress : 5.0%
# Version export complete for folder format
# Downloading Dataset Version Zip in FMD-and-LSD-cattle-disease-3 to folder:: 100%|██████████| 22099/22099 [00:00<00:00, 30575.37it/s]
# Extracting Dataset Version Zip to FMD-and-LSD-cattle-disease-3 in folder:: 100%|██████████| 1898/1898 [00:00<00:00, 7758.01it/s]
# 🔍 Membaca data dari struktur folder...
# Found 1659 images belonging to 4 classes.
# Found 119 images belonging to 4 classes.
# ✅ Ditemukan 4 kelas: ['FMD', 'Healthy', 'LSD', 'non_cattle']
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 224, 224,  │          0 │ input_layer[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv (Conv2D)       │ (None, 112, 112,  │        432 │ rescaling[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_bn             │ (None, 112, 112,  │         64 │ conv[0][0]        │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 112, 112,  │          0 │ conv_bn[0][0]     │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │        144 │ activation[0][0]  │
# │ (DepthwiseConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │         64 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 112, 112,  │          0 │ expanded_conv_de… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │        256 │ re_lu[0][0]       │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_add   │ (None, 112, 112,  │          0 │ activation[0][0], │
# │ (Add)               │ 16)               │            │ expanded_conv_pr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_ex… │ (None, 112, 112,  │      1,024 │ expanded_conv_ad… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_ex… │ (None, 112, 112,  │        256 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 112, 112,  │          0 │ expanded_conv_1_… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 113, 113,  │          0 │ re_lu_1[0][0]     │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 56, 56,    │        576 │ expanded_conv_1_… │
# │ (DepthwiseConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 56, 56,    │        256 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 56, 56,    │          0 │ expanded_conv_1_… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_pr… │ (None, 56, 56,    │      1,536 │ re_lu_2[0][0]     │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_pr… │ (None, 56, 56,    │         96 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_ex… │ (None, 56, 56,    │      1,728 │ expanded_conv_1_… │
# │ (Conv2D)            │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_ex… │ (None, 56, 56,    │        288 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 56, 56,    │          0 │ expanded_conv_2_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_de… │ (None, 56, 56,    │        648 │ re_lu_3[0][0]     │
# │ (DepthwiseConv2D)   │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_de… │ (None, 56, 56,    │        288 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 56, 56,    │          0 │ expanded_conv_2_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_pr… │ (None, 56, 56,    │      1,728 │ re_lu_4[0][0]     │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_pr… │ (None, 56, 56,    │         96 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_add │ (None, 56, 56,    │          0 │ expanded_conv_1_… │
# │ (Add)               │ 24)               │            │ expanded_conv_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_ex… │ (None, 56, 56,    │      1,728 │ expanded_conv_2_… │
# │ (Conv2D)            │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_ex… │ (None, 56, 56,    │        288 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 56, 56,    │          0 │ expanded_conv_3_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 59, 59,    │          0 │ re_lu_5[0][0]     │
# │ (ZeroPadding2D)     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 28, 28,    │      1,800 │ expanded_conv_3_… │
# │ (DepthwiseConv2D)   │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 28, 28,    │        288 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 28, 28,    │          0 │ expanded_conv_3_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 72)  │          0 │ re_lu_6[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 24)  │      1,752 │ expanded_conv_3_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 24)  │          0 │ expanded_conv_3_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 72)  │      1,800 │ expanded_conv_3_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 1, 1, 72)  │          0 │ expanded_conv_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 1, 1, 72)  │          0 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 1, 1, 72)  │          0 │ re_lu_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 28, 28,    │          0 │ re_lu_6[0][0],    │
# │ (Multiply)          │ 72)               │            │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_pr… │ (None, 28, 28,    │      2,880 │ expanded_conv_3_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_pr… │ (None, 28, 28,    │        160 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_ex… │ (None, 28, 28,    │      4,800 │ expanded_conv_3_… │
# │ (Conv2D)            │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_ex… │ (None, 28, 28,    │        480 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 28, 28,    │          0 │ expanded_conv_4_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_de… │ (None, 28, 28,    │      3,000 │ re_lu_8[0][0]     │
# │ (DepthwiseConv2D)   │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_de… │ (None, 28, 28,    │        480 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 28, 28,    │          0 │ expanded_conv_4_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 120) │          0 │ re_lu_9[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 32)  │      3,872 │ expanded_conv_4_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 32)  │          0 │ expanded_conv_4_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 120) │      3,960 │ expanded_conv_4_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 1, 1, 120) │          0 │ expanded_conv_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 1, 1, 120) │          0 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 1, 1, 120) │          0 │ re_lu_10[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 28, 28,    │          0 │ re_lu_9[0][0],    │
# │ (Multiply)          │ 120)              │            │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_pr… │ (None, 28, 28,    │      4,800 │ expanded_conv_4_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_pr… │ (None, 28, 28,    │        160 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_add │ (None, 28, 28,    │          0 │ expanded_conv_3_… │
# │ (Add)               │ 40)               │            │ expanded_conv_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_ex… │ (None, 28, 28,    │      4,800 │ expanded_conv_4_… │
# │ (Conv2D)            │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_ex… │ (None, 28, 28,    │        480 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 28, 28,    │          0 │ expanded_conv_5_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_de… │ (None, 28, 28,    │      3,000 │ re_lu_11[0][0]    │
# │ (DepthwiseConv2D)   │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_de… │ (None, 28, 28,    │        480 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 28, 28,    │          0 │ expanded_conv_5_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 120) │          0 │ re_lu_12[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 32)  │      3,872 │ expanded_conv_5_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 32)  │          0 │ expanded_conv_5_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 120) │      3,960 │ expanded_conv_5_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 1, 1, 120) │          0 │ expanded_conv_5_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 1, 1, 120) │          0 │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 1, 1, 120) │          0 │ re_lu_13[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 28, 28,    │          0 │ re_lu_12[0][0],   │
# │ (Multiply)          │ 120)              │            │ multiply_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_pr… │ (None, 28, 28,    │      4,800 │ expanded_conv_5_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_pr… │ (None, 28, 28,    │        160 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_add │ (None, 28, 28,    │          0 │ expanded_conv_4_… │
# │ (Add)               │ 40)               │            │ expanded_conv_5_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_ex… │ (None, 28, 28,    │      9,600 │ expanded_conv_5_… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_ex… │ (None, 28, 28,    │        960 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 28, 28,    │          0 │ expanded_conv_6_… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 29, 29,    │          0 │ activation_1[0][… │
# │ (ZeroPadding2D)     │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 14, 14,    │      2,160 │ expanded_conv_6_… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 14, 14,    │        960 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 14, 14,    │          0 │ expanded_conv_6_… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_pr… │ (None, 14, 14,    │     19,200 │ activation_2[0][… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_pr… │ (None, 14, 14,    │        320 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_ex… │ (None, 14, 14,    │     16,000 │ expanded_conv_6_… │
# │ (Conv2D)            │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_ex… │ (None, 14, 14,    │        800 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │ (Activation)        │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_de… │ (None, 14, 14,    │      1,800 │ activation_3[0][… │
# │ (DepthwiseConv2D)   │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_de… │ (None, 14, 14,    │        800 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │ (Activation)        │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_pr… │ (None, 14, 14,    │     16,000 │ activation_4[0][… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_pr… │ (None, 14, 14,    │        320 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_add │ (None, 14, 14,    │          0 │ expanded_conv_6_… │
# │ (Add)               │ 80)               │            │ expanded_conv_7_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_ex… │ (None, 14, 14,    │     14,720 │ expanded_conv_7_… │
# │ (Conv2D)            │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_ex… │ (None, 14, 14,    │        736 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 14, 14,    │          0 │ expanded_conv_8_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 14, 14,    │      1,656 │ activation_5[0][… │
# │ (DepthwiseConv2D)   │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 14, 14,    │        736 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 14, 14,    │          0 │ expanded_conv_8_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_pr… │ (None, 14, 14,    │     14,720 │ activation_6[0][… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_pr… │ (None, 14, 14,    │        320 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_add │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │ (Add)               │ 80)               │            │ expanded_conv_8_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_ex… │ (None, 14, 14,    │     14,720 │ expanded_conv_8_… │
# │ (Conv2D)            │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_ex… │ (None, 14, 14,    │        736 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 14, 14,    │          0 │ expanded_conv_9_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_de… │ (None, 14, 14,    │      1,656 │ activation_7[0][… │
# │ (DepthwiseConv2D)   │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_de… │ (None, 14, 14,    │        736 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 14, 14,    │          0 │ expanded_conv_9_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_pr… │ (None, 14, 14,    │     14,720 │ activation_8[0][… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_pr… │ (None, 14, 14,    │        320 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_add │ (None, 14, 14,    │          0 │ expanded_conv_8_… │
# │ (Add)               │ 80)               │            │ expanded_conv_9_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_e… │ (None, 14, 14,    │     38,400 │ expanded_conv_9_… │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_e… │ (None, 14, 14,    │      1,920 │ expanded_conv_10… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 14, 14,    │          0 │ expanded_conv_10… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_d… │ (None, 14, 14,    │      4,320 │ activation_9[0][… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_d… │ (None, 14, 14,    │      1,920 │ expanded_conv_10… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 14, 14,    │          0 │ expanded_conv_10… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 480) │          0 │ activation_10[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 120) │     57,720 │ expanded_conv_10… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 120) │          0 │ expanded_conv_10… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 480) │     58,080 │ expanded_conv_10… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 1, 1, 480) │          0 │ expanded_conv_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 1, 1, 480) │          0 │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 1, 1, 480) │          0 │ re_lu_14[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 14, 14,    │          0 │ activation_10[0]… │
# │ (Multiply)          │ 480)              │            │ multiply_3[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_p… │ (None, 14, 14,    │     53,760 │ expanded_conv_10… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_p… │ (None, 14, 14,    │        448 │ expanded_conv_10… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_e… │ (None, 14, 14,    │     75,264 │ expanded_conv_10… │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_e… │ (None, 14, 14,    │      2,688 │ expanded_conv_11… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 14, 14,    │          0 │ expanded_conv_11… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_d… │ (None, 14, 14,    │      6,048 │ activation_11[0]… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_d… │ (None, 14, 14,    │      2,688 │ expanded_conv_11… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 14, 14,    │          0 │ expanded_conv_11… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 672) │          0 │ activation_12[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 168) │    113,064 │ expanded_conv_11… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 168) │          0 │ expanded_conv_11… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 672) │    113,568 │ expanded_conv_11… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 1, 1, 672) │          0 │ expanded_conv_11… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 1, 1, 672) │          0 │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_4          │ (None, 1, 1, 672) │          0 │ re_lu_15[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 14, 14,    │          0 │ activation_12[0]… │
# │ (Multiply)          │ 672)              │            │ multiply_4[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_p… │ (None, 14, 14,    │     75,264 │ expanded_conv_11… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_p… │ (None, 14, 14,    │        448 │ expanded_conv_11… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_a… │ (None, 14, 14,    │          0 │ expanded_conv_10… │
# │ (Add)               │ 112)              │            │ expanded_conv_11… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_e… │ (None, 14, 14,    │     75,264 │ expanded_conv_11… │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_e… │ (None, 14, 14,    │      2,688 │ expanded_conv_12… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 14, 14,    │          0 │ expanded_conv_12… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_d… │ (None, 17, 17,    │          0 │ activation_13[0]… │
# │ (ZeroPadding2D)     │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_d… │ (None, 7, 7, 672) │     16,800 │ expanded_conv_12… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_d… │ (None, 7, 7, 672) │      2,688 │ expanded_conv_12… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 7, 7, 672) │          0 │ expanded_conv_12… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 672) │          0 │ activation_14[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 168) │    113,064 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 168) │          0 │ expanded_conv_12… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 672) │    113,568 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 1, 1, 672) │          0 │ expanded_conv_12… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 1, 1, 672) │          0 │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_5          │ (None, 1, 1, 672) │          0 │ re_lu_16[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 7, 7, 672) │          0 │ activation_14[0]… │
# │ (Multiply)          │                   │            │ multiply_5[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_p… │ (None, 7, 7, 160) │    107,520 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_p… │ (None, 7, 7, 160) │        640 │ expanded_conv_12… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_e… │ (None, 7, 7, 960) │    153,600 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_e… │ (None, 7, 7, 960) │      3,840 │ expanded_conv_13… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 7, 7, 960) │          0 │ expanded_conv_13… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_d… │ (None, 7, 7, 960) │     24,000 │ activation_15[0]… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_d… │ (None, 7, 7, 960) │      3,840 │ expanded_conv_13… │
# ...
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 7, 7, 960) │          0 │ activation_18[0]… │
# │ (Multiply)          │                   │            │ multiply_7[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_p… │ (None, 7, 7, 160) │    153,600 │ expanded_conv_14… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_p… │ (None, 7, 7, 160) │        640 │ expanded_conv_14… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_a… │ (None, 7, 7, 160) │          0 │ expanded_conv_13… │
# │ (Add)               │                   │            │ expanded_conv_14… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_1 (Conv2D)     │ (None, 7, 7, 960) │    153,600 │ expanded_conv_14… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_1_bn           │ (None, 7, 7, 960) │      3,840 │ conv_1[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 7, 7, 960) │          0 │ conv_1_bn[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 960)       │          0 │ activation_19[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │    123,008 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 4)         │        516 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,119,876 (11.90 MB)
#  Trainable params: 123,524 (482.52 KB)
#  Non-trainable params: 2,996,352 (11.43 MB)
# 🚀 Memulai training MobileNetV3Large selama 50 epoch...
# Epoch 1/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.6684 - loss: 0.9472
# Epoch 1: val_accuracy improved from None to 0.93277, saving model to /content/tes1_best_v3.keras
#
# Epoch 1: finished saving model to /content/tes1_best_v3.keras
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 54s 646ms/step - accuracy: 0.8216 - loss: 0.5153 - val_accuracy: 0.9328 - val_loss: 0.2096
# Epoch 2/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9684 - loss: 0.1106
# Epoch 2: val_accuracy did not improve from 0.93277
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9765 - loss: 0.0919 - val_accuracy: 0.9328 - val_loss: 0.1838
# Epoch 3/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9948 - loss: 0.0383
# Epoch 3: val_accuracy improved from 0.93277 to 0.94958, saving model to /content/tes1_best_v3.keras
#
# Epoch 3: finished saving model to /content/tes1_best_v3.keras
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - accuracy: 0.9958 - loss: 0.0335 - val_accuracy: 0.9496 - val_loss: 0.1621
# Epoch 4/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9968 - loss: 0.0240
# Epoch 4: val_accuracy did not improve from 0.94958
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.9976 - loss: 0.0212 - val_accuracy: 0.9496 - val_loss: 0.1659
# Epoch 5/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0108
# Epoch 5: val_accuracy did not improve from 0.94958
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 0.9412 - val_loss: 0.1590
# Epoch 6/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0085
# Epoch 6: val_accuracy did not improve from 0.94958
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.9412 - val_loss: 0.1744
# Epoch 7/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0066
# Epoch 7: val_accuracy did not improve from 0.94958
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.9412 - val_loss: 0.1729
# Epoch 8/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0045
# Epoch 8: val_accuracy did not improve from 0.94958
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.9328 - val_loss: 0.1908
# Epoch 9/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 9: val_accuracy did not improve from 0.94958
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9496 - val_loss: 0.1788
# Epoch 10/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 10: val_accuracy did not improve from 0.94958
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9412 - val_loss: 0.1909
# Epoch 11/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0034
# Epoch 11: val_accuracy improved from 0.94958 to 0.96639, saving model to /content/tes1_best_v3.keras
#
# Epoch 11: finished saving model to /content/tes1_best_v3.keras
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.9664 - val_loss: 0.1713
# Epoch 12/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 12: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9412 - val_loss: 0.1692
# Epoch 13/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 13: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9412 - val_loss: 0.1928
# Epoch 14/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 14: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9412 - val_loss: 0.1888
# Epoch 15/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 15: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9496 - val_loss: 0.1792
# Epoch 16/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 16: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9412 - val_loss: 0.1918
# Epoch 17/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 8.6938e-04
# Epoch 17: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 1.0000 - loss: 9.1212e-04 - val_accuracy: 0.9412 - val_loss: 0.1831
# Epoch 18/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 8.0748e-04
# Epoch 18: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - accuracy: 1.0000 - loss: 9.0954e-04 - val_accuracy: 0.9412 - val_loss: 0.1964
# Epoch 19/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 19: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9412 - val_loss: 0.1870
# Epoch 20/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 8.0069e-04
# Epoch 20: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 1.0000 - loss: 7.1935e-04 - val_accuracy: 0.9412 - val_loss: 0.1896
# Epoch 21/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 5.7873e-04
# Epoch 21: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 1.0000 - loss: 6.9228e-04 - val_accuracy: 0.9328 - val_loss: 0.2037
# Epoch 22/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 7.0847e-04
# Epoch 22: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 1.0000 - loss: 8.0987e-04 - val_accuracy: 0.9412 - val_loss: 0.2111
# Epoch 23/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 6.5365e-04
# Epoch 23: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 1.0000 - loss: 6.3975e-04 - val_accuracy: 0.9412 - val_loss: 0.2151
# Epoch 24/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 5.5177e-04
# Epoch 24: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 1.0000 - loss: 5.5509e-04 - val_accuracy: 0.9412 - val_loss: 0.2163
# Epoch 25/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 4.2947e-04
# Epoch 25: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 1.0000 - loss: 4.3891e-04 - val_accuracy: 0.9412 - val_loss: 0.2219
# Epoch 26/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 6.4088e-04
# Epoch 26: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 1.0000 - loss: 5.7755e-04 - val_accuracy: 0.9412 - val_loss: 0.2234
# Epoch 27/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 4.8174e-04
# Epoch 27: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 1.0000 - loss: 5.6453e-04 - val_accuracy: 0.9412 - val_loss: 0.2339
# Epoch 28/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 7.1245e-04
# Epoch 28: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9412 - val_loss: 0.2030
# Epoch 29/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 8.9005e-04
# Epoch 29: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 1.0000 - loss: 8.2551e-04 - val_accuracy: 0.9412 - val_loss: 0.2088
# Epoch 30/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 4.5985e-04
# Epoch 30: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - accuracy: 1.0000 - loss: 4.6971e-04 - val_accuracy: 0.9412 - val_loss: 0.2166
# Epoch 31/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 3.2864e-04
# Epoch 31: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 1.0000 - loss: 3.2787e-04 - val_accuracy: 0.9412 - val_loss: 0.2163
# Epoch 32/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 2.6955e-04
# Epoch 32: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 1.0000 - loss: 3.5231e-04 - val_accuracy: 0.9496 - val_loss: 0.2086
# Epoch 33/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 3.7644e-04
# Epoch 33: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 1.0000 - loss: 4.9456e-04 - val_accuracy: 0.9412 - val_loss: 0.2174
# Epoch 34/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 3.6817e-04
# Epoch 34: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 1.0000 - loss: 3.1819e-04 - val_accuracy: 0.9412 - val_loss: 0.2078
# Epoch 35/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 3.2039e-04
# Epoch 35: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 1.0000 - loss: 2.8043e-04 - val_accuracy: 0.9328 - val_loss: 0.2220
# Epoch 36/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 3.9435e-04
# Epoch 36: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 3.7359e-04 - val_accuracy: 0.9412 - val_loss: 0.1988
# Epoch 37/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 2.4035e-04
# Epoch 37: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 1.0000 - loss: 2.0740e-04 - val_accuracy: 0.9412 - val_loss: 0.2129
# Epoch 38/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 3.1007e-04
# Epoch 38: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 1.0000 - loss: 2.8702e-04 - val_accuracy: 0.9412 - val_loss: 0.2137
# Epoch 39/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.9208e-04
# Epoch 39: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 1.0000 - loss: 1.7094e-04 - val_accuracy: 0.9328 - val_loss: 0.2156
# Epoch 40/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 1.8615e-04
# Epoch 40: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 2.0079e-04 - val_accuracy: 0.9328 - val_loss: 0.2151
# Epoch 41/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.8828e-04
# Epoch 41: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 1.0000 - loss: 1.5414e-04 - val_accuracy: 0.9412 - val_loss: 0.2135
# Epoch 42/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.5238e-04
# Epoch 42: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - accuracy: 1.0000 - loss: 1.8471e-04 - val_accuracy: 0.9412 - val_loss: 0.2155
# Epoch 43/50
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.2649e-04
# Epoch 43: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 1.0000 - loss: 1.4088e-04 - val_accuracy: 0.9412 - val_loss: 0.2210
# Epoch 44/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.7600e-04
# Epoch 44: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 1.0000 - loss: 1.5685e-04 - val_accuracy: 0.9496 - val_loss: 0.2228
# Epoch 45/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 1.2061e-04
# Epoch 45: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 1.0000 - loss: 1.3538e-04 - val_accuracy: 0.9328 - val_loss: 0.2366
# Epoch 46/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 1.0630e-04
# Epoch 46: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 1.0000 - loss: 9.4664e-05 - val_accuracy: 0.9328 - val_loss: 0.2312
# Epoch 47/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 8.2399e-05
# Epoch 47: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 1.0000 - loss: 9.3086e-05 - val_accuracy: 0.9328 - val_loss: 0.2302
# Epoch 48/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 2.5341e-04
# Epoch 48: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 1.0000 - loss: 3.0734e-04 - val_accuracy: 0.9496 - val_loss: 0.2339
# Epoch 49/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.8737e-04
# Epoch 49: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 1.5937e-04 - val_accuracy: 0.9328 - val_loss: 0.2343
# Epoch 50/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.7435e-04
# Epoch 50: val_accuracy did not improve from 0.96639
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 1.0000 - loss: 1.5369e-04 - val_accuracy: 0.9496 - val_loss: 0.2381
#
# ✅ Training selesai.
# 🏆 Best model : /content/tes1_best_v3.keras
# 📌 Last model : /content/tes1_last_v3.keras

# %% [markdown]
# # Testing

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
import json
import matplotlib.pyplot as plt
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input

def prediksi_mobilenet(image_path, model_path, class_json_path):
    # 1. Memuat model dan file JSON berisi nama kelas
    try:
        model = load_model(model_path)
        with open(class_json_path, 'r') as f:
            # Karena JSON key selalu string (misal: "0", "1"), kita biarkan aslinya
            class_names = json.load(f)
    except Exception as e:
        print("❌ ERROR: Gagal memuat model atau file JSON kelas.")
        print(e)
        return {"predictions": []}

    print(f"\n📦 Memulai prediksi pada gambar: {image_path}")

    # 2. Memuat dan memproses gambar uji (harus disamakan dengan saat training: 224x224 dan rescale 1/255)
    img = image.load_img(image_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)


    # 3. Melakukan inferensi / tebakan model
    predictions = model.predict(img_array, verbose=0)
    print("\nProbabilitas setiap kelas:")
    for idx, prob in enumerate(predictions[0]):
        print(f"{class_names[str(idx)]}: {prob:.4f}")


    # 4. Mencari kelas dengan probabilitas / confidence tertinggi
    predicted_class_idx = np.argmax(predictions[0])
    confidence = float(predictions[0][predicted_class_idx])

    # Mengambil nama label berdasarkan index (mengubah index ke string untuk mencocokkan key JSON)
    predicted_label = class_names[str(predicted_class_idx)]

    # 5. Menampilkan gambar dan hasil prediksi
    print("\n✅ Hasil Visual Klasifikasi:")
    plt.imshow(img)
    plt.title(f"{predicted_label.upper()} (Conf: {confidence:.2f})")
    plt.axis('off')
    plt.show()

    # 6. Menyusun Output dalam format JSON
    json_output = {
        "predictions": [
            {
                "class": predicted_label,
                "class_id": int(predicted_class_idx),
                "confidence": confidence
            }
        ]
    }

    print(f"\n💡 Kesimpulan Prediksi:")
    print(f"    - Terdeteksi sebagai: {predicted_label.upper()}")
    print(f"    - Tingkat keyakinan: {confidence * 100:.2f}%")

    print("\n📄 Output JSON:")
    print(json.dumps(json_output, indent=2))

    return json_output

# ==========================================
# KONFIGURASI PENGUJIAN (UBAH BAGIAN INI)
# ==========================================
MODEL_PATH = '/content/tes1_best_v3.keras'
CLASS_JSON = '/content/class_names.json'

# Ganti dengan path/nama file gambar yang baru Anda upload ke Colab
GAMBAR_UJI = '/content/kucing.jpeg'

# Jalankan fungsi prediksi
hasil = prediksi_mobilenet(GAMBAR_UJI, MODEL_PATH, CLASS_JSON)
# Out:
# 📦 Memulai prediksi pada gambar: /content/kucing.jpeg
#
# Probabilitas setiap kelas:
# FMD: 0.0002
# Healthy: 0.0039
# LSD: 0.0000
# non_cattle: 0.9959
#
# ✅ Hasil Visual Klasifikasi:
# 💡 Kesimpulan Prediksi:
#     - Terdeteksi sebagai: NON_CATTLE
#     - Tingkat keyakinan: 99.59%
#
# 📄 Output JSON:
# {
#   "predictions": [
#     {
#       "class": "non_cattle",
#       "class_id": 3,
#       "confidence": 0.9959253668785095
#     }
#   ]
# }

# %% [markdown]
# Confusion Matrix

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input

# 1. Load model
MODEL_PATH = '/content/tes1_best_v3.keras'
model = load_model(MODEL_PATH)

# 2. Definisikan direktori validasi/test
VALID_DIR = '/content/FMD-and-LSD-cattle-disease-3/valid'  # <-- sesuaikan

# 3. BUAT ulang generator (WAJIB, walau sudah training sebelumnya)
valid_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

valid_generator_cm = valid_datagen.flow_from_directory(
    VALID_DIR,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# 4. Ambil label asli
y_true = valid_generator_cm.classes
nama_kelas = list(valid_generator_cm.class_indices.keys())

# 5. Prediksi
# Tambahkan ini di poin 5 kode Anda
print("⏳ Predicting...")
y_pred_probs = model.predict(valid_generator_cm)

# Lihat 5 prediksi pertama
print("Contoh Probabilitas (FMD, LSD, Healthy):")
print(y_pred_probs[:5])

y_pred = np.argmax(y_pred_probs, axis=1)

#y_pred_probs = model.predict(valid_generator_cm)
#y_pred = np.argmax(y_pred_probs, axis=1)

# 6. Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=nama_kelas,
            yticklabels=nama_kelas)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# 7. Classification Report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=nama_kelas))
# Out:
# Found 119 images belonging to 4 classes.
# ⏳ Predicting...
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7c3114472160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step
# Contoh Probabilitas (FMD, LSD, Healthy):
# [[9.9999762e-01 1.8896362e-08 2.3255184e-06 1.5655626e-08]
#  [9.9964249e-01 3.6270518e-05 1.7085253e-05 3.0417365e-04]
#  [9.9836308e-01 1.4718218e-03 1.2377651e-04 4.1359235e-05]
#  [9.9921787e-01 1.0676803e-04 4.6501295e-08 6.7538506e-04]
#  [9.9999022e-01 1.3165384e-06 1.7873947e-07 8.3634450e-06]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          FMD       0.97      1.00      0.98        30
#      Healthy       0.92      0.92      0.92        26
#          LSD       1.00      0.94      0.97        36
#   non_cattle       0.96      1.00      0.98        27
#
#     accuracy                           0.97       119
#    macro avg       0.96      0.97      0.96       119
# weighted avg       0.97      0.97      0.97       119

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input

# 1. Load model
MODEL_PATH = '/content/tes1_last_v3.keras'
model = load_model(MODEL_PATH)

# 2. Definisikan direktori validasi/test
VALID_DIR = '/content/FMD-and-LSD-cattle-disease-3/valid'  # <-- sesuaikan

# 3. BUAT ulang generator (WAJIB, walau sudah training sebelumnya)
valid_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

valid_generator_cm = valid_datagen.flow_from_directory(
    VALID_DIR,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# 4. Ambil label asli
y_true = valid_generator_cm.classes
nama_kelas = list(valid_generator_cm.class_indices.keys())

# 5. Prediksi
# Tambahkan ini di poin 5 kode Anda
print("⏳ Predicting...")
y_pred_probs = model.predict(valid_generator_cm)

# Lihat 5 prediksi pertama
print("Contoh Probabilitas (FMD, LSD, Healthy):")
print(y_pred_probs[:5])

y_pred = np.argmax(y_pred_probs, axis=1)

#y_pred_probs = model.predict(valid_generator_cm)
#y_pred = np.argmax(y_pred_probs, axis=1)

# 6. Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=nama_kelas,
            yticklabels=nama_kelas)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# 7. Classification Report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=nama_kelas))
# Out:
# Found 119 images belonging to 4 classes.
# ⏳ Predicting...
# WARNING:tensorflow:6 out of the last 8 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7c310e3b0180> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step
# Contoh Probabilitas (FMD, LSD, Healthy):
# [[1.0000000e+00 1.0864738e-11 5.2127305e-08 7.0872398e-11]
#  [9.9999881e-01 2.2104544e-08 6.3851672e-08 1.0789191e-06]
#  [9.9994898e-01 4.2470190e-05 4.6866635e-06 3.9122110e-06]
#  [9.9999642e-01 1.8907414e-07 2.5450668e-11 3.4358141e-06]
#  [1.0000000e+00 3.6524192e-10 2.5777114e-10 2.8295103e-08]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          FMD       0.97      1.00      0.98        30
#      Healthy       0.92      0.85      0.88        26
#          LSD       0.97      0.94      0.96        36
#   non_cattle       0.93      1.00      0.96        27
#
#     accuracy                           0.95       119
#    macro avg       0.95      0.95      0.95       119
# weighted avg       0.95      0.95      0.95       119

# %%
print(model.names)

# %%
print(model.task)
# Out:
# detect

# %% [markdown]
# **Reformat/Convert to Tflite**

# %%
import tensorflow as tf

model = tf.keras.models.load_model("tes1_best_v3.keras")

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# Default = float32
tflite_model_fp32 = converter.convert()

with open("model_fp32.tflite", "wb") as f:
    f.write(tflite_model_fp32)

print("Sukses membuat model_fp32.tflite")
# Out:
# Saved artifact at '/tmp/tmp64x42gys'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   139296500470160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500469200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500469392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500469776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500465744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500470352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500468816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500469008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500470928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500467088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500466320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500468048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500466896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500469968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500465936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500468240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500468432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500468624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500469584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500471696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500471312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500471120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500471504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500467856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500472656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500472080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500472272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500472464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500466512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500473616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500473040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500473232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500473424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500470736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500474576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500474000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500474192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500474384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500471888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500475536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500474960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500475152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500475344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500472848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500476496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500475920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500476112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500476304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500473808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500477456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500476880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500477072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500477264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500474768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500478416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500477840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500475728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500479184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500478608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500479568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500478032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500476688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500479376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500480144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500478800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500477648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500479952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500478224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500481104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500480528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500480720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500480336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500481872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500481296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500479760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500480912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500481680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500478992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500481488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327156944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327156752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327156368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327157520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327155984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327157136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327157328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327156560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327158480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327157904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327158096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327158288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327156176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327159440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327158864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327155792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327160208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327159632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327160592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327159056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327157712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327160400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327161168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327159824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327158672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327160976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327159248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327162128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327161552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327161744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327161936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327160016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327163088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327162512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327162704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327162896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327160784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327164048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327163472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327163664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327163856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327161360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327165008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327164432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327164624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327164816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327162320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327165968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327165392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327165584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327165776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327163280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327166928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327166352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327166544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327166736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327164240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327167888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327167312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327167504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327167696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327165200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327168848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327168272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327168464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327168656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327166160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327169808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327169232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327169424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327169616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327167120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327170768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327170192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327170384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327170576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327168080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327171728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327171152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327170000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327171536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327171344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327170960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327169040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360514576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360514384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327171920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360515152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360513808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360514768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360514960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360514000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360516112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360515536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360513616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360516880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360516304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360517264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360515728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360514192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360517072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360517840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360516496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360515344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360517648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360515920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360518800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360518224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360518416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360518608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360516688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360519760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360519184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360517456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360520528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360519952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360520912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360519376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360518032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360520720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360521488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360520144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360518992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360521296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360519568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360522448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360521872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360522064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360522256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360520336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360523408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360522832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360521104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360524176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360523600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360524560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360523024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360521680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360524368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360525136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360523792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360522640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360524944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360523216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360526096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360525520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360525712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360525904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360523984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360527056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360526480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360524752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360527824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360527248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360528208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360526672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360525328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360528016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360528784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360527440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360526288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360529168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360526864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360529744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360528592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360529360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360527632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360529552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360528976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360528400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512590480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512591440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512589904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512591824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512591056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512590672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512591632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512592400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512590096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512590288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512592208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512590864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512593360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512592784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512591248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512592976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512592592: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Sukses membuat model_fp32.tflite

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# Optimasi
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# Float16 quantization
converter.target_spec.supported_types = [tf.float16]

tflite_model_fp16 = converter.convert()

with open("model_fp16.tflite", "wb") as f:
    f.write(tflite_model_fp16)

print("Sukses membuat model_fp16.tflite")
# Out:
# Saved artifact at '/tmp/tmpogyxdpwk'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   139296500470160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500469200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500469392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500469776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500465744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500470352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500468816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500469008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500470928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500467088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500466320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500468048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500466896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500469968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500465936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500468240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500468432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500468624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500469584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500471696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500471312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500471120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500471504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500467856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500472656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500472080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500472272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500472464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500466512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500473616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500473040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500473232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500473424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500470736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500474576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500474000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500474192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500474384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500471888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500475536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500474960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500475152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500475344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500472848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500476496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500475920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500476112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500476304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500473808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500477456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500476880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500477072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500477264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500474768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500478416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500477840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500475728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500479184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500478608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500479568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500478032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500476688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500479376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500480144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500478800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500477648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500479952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500478224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500481104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500480528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500480720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500480336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500481872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500481296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500479760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500480912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500481680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500478992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296500481488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327156944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327156752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327156368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327157520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327155984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327157136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327157328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327156560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327158480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327157904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327158096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327158288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327156176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327159440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327158864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327155792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327160208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327159632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327160592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327159056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327157712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327160400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327161168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327159824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327158672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327160976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327159248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327162128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327161552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327161744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327161936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327160016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327163088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327162512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327162704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327162896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327160784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327164048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327163472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327163664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327163856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327161360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327165008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327164432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327164624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327164816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327162320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327165968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327165392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327165584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327165776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327163280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327166928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327166352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327166544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327166736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327164240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327167888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327167312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327167504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327167696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327165200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327168848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327168272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327168464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327168656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327166160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327169808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327169232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327169424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327169616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327167120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327170768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327170192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327170384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327170576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327168080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327171728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327171152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327170000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327171536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327171344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327170960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327169040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360514576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360514384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296327171920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360515152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360513808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360514768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360514960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360514000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360516112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360515536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360513616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360516880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360516304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360517264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360515728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360514192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360517072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360517840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360516496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360515344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360517648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360515920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360518800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360518224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360518416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360518608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360516688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360519760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360519184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360517456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360520528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360519952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360520912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360519376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360518032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360520720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360521488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360520144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360518992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360521296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360519568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360522448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360521872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360522064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360522256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360520336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360523408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360522832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360521104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360524176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360523600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360524560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360523024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360521680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360524368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360525136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360523792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360522640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360524944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360523216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360526096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360525520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360525712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360525904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360523984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360527056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360526480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360524752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360527824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360527248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360528208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360526672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360525328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360528016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360528784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360527440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360526288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360529168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360526864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360529744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360528592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360529360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360527632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360529552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360528976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296360528400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512590480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512591440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512589904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512591824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512591056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512590672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512591632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512592400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512590096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512590288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512592208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512590864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512593360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512592784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512591248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512592976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139296512592592: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Sukses membuat model_fp16.tflite

# %% [markdown]
# Cek Input/Output Shape Model

# %%
# Install TFLite tools (jika belum)
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (26.1)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.19.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2026.4.22)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.10.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)

# %%
# Cek model info
import tensorflow as tf;
interpreter = tf.lite.Interpreter(model_path='/content/model.tflite');
interpreter.allocate_tensors();
print('Input:', interpreter.get_input_details());
print('Output:', interpreter.get_output_details())
# Out:
# Input: [{'name': 'images', 'index': 0, 'shape': array([  1, 640, 640,   3], dtype=int32), 'shape_signature': array([  1, 640, 640,   3], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# Output: [{'name': 'Identity', 'index': 611, 'shape': array([   1,    8, 8400], dtype=int32), 'shape_signature': array([   1,    8, 8400], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
